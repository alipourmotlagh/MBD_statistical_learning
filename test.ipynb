# %%
install.packages('gifski')
install.packages('png')
# Out:
# package 'gifski' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\malipourmotlagh1\AppData\Local\Temp\RtmpUjjPbx\downloaded_packages
# package 'png' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\malipourmotlagh1\AppData\Local\Temp\RtmpUjjPbx\downloaded_packages

# %%
library(ggplot2)
library(gganimate)
theme_set(theme_bw())
library(gapminder)
head(gapminder)
library(gifski)
library(png)
# Out:
#   country     continent year lifeExp pop      gdpPercap
# 1 Afghanistan Asia      1952 28.801   8425333 779.4453
# 2 Afghanistan Asia      1957 30.332   9240934 820.8530
# 3 Afghanistan Asia      1962 31.997  10267083 853.1007
# 4 Afghanistan Asia      1967 34.020  11537966 836.1971
# 5 Afghanistan Asia      1972 36.088  13079460 739.9811
# 6 Afghanistan Asia      1977 38.438  14880372 786.1134

# %%
p <- ggplot(
  gapminder, 
  aes(x = gdpPercap, y=lifeExp, size = pop, colour = country)
  ) +
  geom_point(show.legend = FALSE, alpha = 0.7) +
  scale_color_viridis_d() +
  scale_size(range = c(2, 12)) +
  scale_x_log10() +
  labs(x = "GDP per capita", y = "Life expectancy")
p
# Out:
# plot without title

# %%
p + transition_time(year) +
  labs(title = "Year: {frame_time}")
# Out:
# Rendering [>---------------------------------------------] at 4 fps ~ eta: 24s
#
# Rendering [>-------------------------------------------] at 4.4 fps ~ eta: 22s
#
# Rendering [=>------------------------------------------] at 4.6 fps ~ eta: 21s
#
# Rendering [==>-----------------------------------------] at 4.6 fps ~ eta: 20s
#
# Rendering [==>-----------------------------------------] at 4.8 fps ~ eta: 20s
#
# Rendering [===>----------------------------------------] at 4.7 fps ~ eta: 19s
#
# Rendering [===>----------------------------------------] at 4.8 fps ~ eta: 19s
#
# Rendering [===>----------------------------------------] at 4.9 fps ~ eta: 19s
#
# Rendering [====>---------------------------------------] at 4.9 fps ~ eta: 18s
#
# Rendering [=====>----------------------------------------] at 5 fps ~ eta: 18s
#
# Rendering [=====>----------------------------------------] at 5 fps ~ eta: 17s
#
# Rendering [======>-------------------------------------] at 4.8 fps ~ eta: 18s
#
# Rendering [======>-------------------------------------] at 4.8 fps ~ eta: 17s
#
# Rendering [=======>------------------------------------] at 4.8 fps ~ eta: 17s
#
# Rendering [=======>------------------------------------] at 4.9 fps ~ eta: 17s
#
# Rendering [========>-----------------------------------] at 4.9 fps ~ eta: 16s
#
# Rendering [=========>------------------------------------] at 5 fps ~ eta: 16s
#
# Rendering [==========>-----------------------------------] at 5 fps ~ eta: 15s
#
# Rendering [==========>---------------------------------] at 4.9 fps ~ eta: 15s
#
# Rendering [===========>----------------------------------] at 5 fps ~ eta: 15s
#
# Rendering [===========>--------------------------------] at 4.9 fps ~ eta: 15s
#
# Rendering [============>-------------------------------] at 4.9 fps ~ eta: 14s
#
# Rendering [=============>--------------------------------] at 5 fps ~ eta: 14s
#
# Rendering [==============>-------------------------------] at 5 fps ~ eta: 14s
#
# Rendering [==============>-------------------------------] at 5 fps ~ eta: 13s
#
# Rendering [===============>------------------------------] at 5 fps ~ eta: 13s
#
# Rendering [================>-----------------------------] at 5 fps ~ eta: 13s
#
# Rendering [================>-----------------------------] at 5 fps ~ eta: 12s
#
# Rendering [================>---------------------------] at 5.1 fps ~ eta: 12s
#
# Rendering [=================>--------------------------] at 5.1 fps ~ eta: 12s
#
# Rendering [=================>--------------------------] at 5.1 fps ~ eta: 11s
#
# Rendering [==================>-------------------------] at 5.1 fps ~ eta: 11s
#
# Rendering [===================>------------------------] at 5.1 fps ~ eta: 11s
#
# Rendering [====================>-----------------------] at 5.1 fps ~ eta: 10s
#
# Rendering [=====================>----------------------] at 5.1 fps ~ eta: 10s
#
# Rendering [======================>---------------------] at 5.1 fps ~ eta:  9s
#
# Rendering [========================>---------------------] at 5 fps ~ eta:  9s
#
# Rendering [=========================>--------------------] at 5 fps ~ eta:  9s
#
# Rendering [==========================>-------------------] at 5 fps ~ eta:  8s
#
# Rendering [===========================>------------------] at 5 fps ~ eta:  8s
#
# Rendering [==========================>-----------------] at 4.9 fps ~ eta:  8s
#
# Rendering [===========================>----------------] at 4.9 fps ~ eta:  8s
#
# Rendering [===========================>----------------] at 4.9 fps ~ eta:  7s
#
# Rendering [============================>---------------] at 4.9 fps ~ eta:  7s
#
# Rendering [=============================>--------------] at 4.9 fps ~ eta:  7s
#
# Rendering [=============================>--------------] at 4.9 fps ~ eta:  6s
#
# Rendering [==============================>-------------] at 4.8 fps ~ eta:  6s
#
# Rendering [===============================>------------] at 4.8 fps ~ eta:  6s
#
# Rendering [================================>-----------] at 4.8 fps ~ eta:  5s
#
# Rendering [=================================>----------] at 4.8 fps ~ eta:  5s
#
# Rendering [==================================>---------] at 4.8 fps ~ eta:  4s
#
# Rendering [===================================>--------] at 4.8 fps ~ eta:  4s
#
# Rendering [====================================>-------] at 4.8 fps ~ eta:  4s
#
# Rendering [====================================>-------] at 4.8 fps ~ eta:  3s
#
# Rendering [=====================================>------] at 4.8 fps ~ eta:  3s
#
# Rendering [======================================>-----] at 4.8 fps ~ eta:  2s
#
# Rendering [=======================================>----] at 4.9 fps ~ eta:  2s
#
# Rendering [========================================>---] at 4.9 fps ~ eta:  1s
#
# Rendering [=========================================>--] at 4.9 fps ~ eta:  1s
#
# Rendering [==========================================>-] at 4.9 fps ~ eta:  1s
#
# Rendering [==========================================>-] at 4.9 fps ~ eta:  0s
#
# Rendering [===========================================>] at 4.9 fps ~ eta:  0s
#
# Rendering [============================================] at 4.9 fps ~ eta:  0s
#
#
# Warning message:
# "file_renderer failed to copy frames to the destination directory"
# ERROR while rich displaying an object: Error in loadNamespace(name): there is no package called 'plotly'
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_plotly1.ggplot(obj)
# 9. fromJSON(plotly::plotly_json(obj, jsonedit = FALSE))
# 10. plotly::plotly_json
# 11. getExportedValue(pkg, name)
# 12. asNamespace(ns)
# 13. getNamespace(ns)
# 14. loadNamespace(name)
# 15. withRestarts(stop(cond), retry_loadNamespace = function() NULL)
# 16. withOneRestart(expr, restarts[[1L]])
# 17. doWithOneRestart(return(expr), restart)
#   [1] "./gganim_plot0001.png" "./gganim_plot0002.png" "./gganim_plot0003.png"
#   [4] "./gganim_plot0004.png" "./gganim_plot0005.png" "./gganim_plot0006.png"
#   [7] "./gganim_plot0007.png" "./gganim_plot0008.png" "./gganim_plot0009.png"
#  [10] "./gganim_plot0010.png" "./gganim_plot0011.png" "./gganim_plot0012.png"
#  [13] "./gganim_plot0013.png" "./gganim_plot0014.png" "./gganim_plot0015.png"
#  [16] "./gganim_plot0016.png" "./gganim_plot0017.png" "./gganim_plot0018.png"
#  [19] "./gganim_plot0019.png" "./gganim_plot0020.png" "./gganim_plot0021.png"
#  [22] "./gganim_plot0022.png" "./gganim_plot0023.png" "./gganim_plot0024.png"
#  [25] "./gganim_plot0025.png" "./gganim_plot0026.png" "./gganim_plot0027.png"
#  [28] "./gganim_plot0028.png" "./gganim_plot0029.png" "./gganim_plot0030.png"
#  [31] "./gganim_plot0031.png" "./gganim_plot0032.png" "./gganim_plot0033.png"
#  [34] "./gganim_plot0034.png" "./gganim_plot0035.png" "./gganim_plot0036.png"
#  [37] "./gganim_plot0037.png" "./gganim_plot0038.png" "./gganim_plot0039.png"
#  [40] "./gganim_plot0040.png" "./gganim_plot0041.png" "./gganim_plot0042.png"
#  [43] "./gganim_plot0043.png" "./gganim_plot0044.png" "./gganim_plot0045.png"
#  [46] "./gganim_plot0046.png" "./gganim_plot0047.png" "./gganim_plot0048.png"
#  [49] "./gganim_plot0049.png" "./gganim_plot0050.png" "./gganim_plot0051.png"
#  [52] "./gganim_plot0052.png" "./gganim_plot0053.png" "./gganim_plot0054.png"
#  [55] "./gganim_plot0055.png" "./gganim_plot0056.png" "./gganim_plot0057.png"
#  [58] "./gganim_plot0058.png" "./gganim_plot0059.png" "./gganim_plot0060.png"
#  [61] "./gganim_plot0061.png" "./gganim_plot0062.png" "./gganim_plot0063.png"
#  [64] "./gganim_plot0064.png" "./gganim_plot0065.png" "./gganim_plot0066.png"
#  [67] "./gganim_plot0067.png" "./gganim_plot0068.png" "./gganim_plot0069.png"
#  [70] "./gganim_plot0070.png" "./gganim_plot0071.png" "./gganim_plot0072.png"
#  [73] "./gganim_plot0073.png" "./gganim_plot0074.png" "./gganim_plot0075.png"
#  [76] "./gganim_plot0076.png" "./gganim_plot0077.png" "./gganim_plot0078.png"
#  [79] "./gganim_plot0079.png" "./gganim_plot0080.png" "./gganim_plot0081.png"
#  [82] "./gganim_plot0082.png" "./gganim_plot0083.png" "./gganim_plot0084.png"
#  [85] "./gganim_plot0085.png" "./gganim_plot0086.png" "./gganim_plot0087.png"
#  [88] "./gganim_plot0088.png" "./gganim_plot0089.png" "./gganim_plot0090.png"
#  [91] "./gganim_plot0091.png" "./gganim_plot0092.png" "./gganim_plot0093.png"
#  [94] "./gganim_plot0094.png" "./gganim_plot0095.png" "./gganim_plot0096.png"
#  [97] "./gganim_plot0097.png" "./gganim_plot0098.png" "./gganim_plot0099.png"
# [100] "./gganim_plot0100.png"
# attr(,"frame_vars")
#     frame nframes progress frame_time
# 1       1     100     0.01       1952
# 2       2     100     0.02       1953
# 3       3     100     0.03       1953
# 4       4     100     0.04       1954
# 5       5     100     0.05       1954
# 6       6     100     0.06       1955
# 7       7     100     0.07       1955
# 8       8     100     0.08       1956
# 9       9     100     0.09       1956
# 10     10     100     0.10       1957
# 11     11     100     0.11       1958
# 12     12     100     0.12       1958
# 13     13     100     0.13       1959
# 14     14     100     0.14       1959
# 15     15     100     0.15       1960
# 16     16     100     0.16       1960
# 17     17     100     0.17       1961
# 18     18     100     0.18       1961
# 19     19     100     0.19       1962
# 20     20     100     0.20       1963
# 21     21     100     0.21       1963
# 22     22     100     0.22       1964
# 23     23     100     0.23       1964
# 24     24     100     0.24       1965
# 25     25     100     0.25       1965
# 26     26     100     0.26       1966
# 27     27     100     0.27       1966
# 28     28     100     0.28       1967
# 29     29     100     0.29       1968
# 30     30     100     0.30       1968
# 31     31     100     0.31       1969
# 32     32     100     0.32       1969
# 33     33     100     0.33       1970
# 34     34     100     0.34       1970
# 35     35     100     0.35       1971
# 36     36     100     0.36       1971
# 37     37     100     0.37       1972
# 38     38     100     0.38       1973
# 39     39     100     0.39       1973
# 40     40     100     0.40       1974
# 41     41     100     0.41       1974
# 42     42     100     0.42       1975
# 43     43     100     0.43       1975
# 44     44     100     0.44       1976
# 45     45     100     0.45       1976
# 46     46     100     0.46       1977
# 47     47     100     0.47       1978
# 48     48     100     0.48       1978
# 49     49     100     0.49       1979
# 50     50     100     0.50       1979
# 51     51     100     0.51       1980
# 52     52     100     0.52       1980
# 53     53     100     0.53       1981
# 54     54     100     0.54       1981
# 55     55     100     0.55       1982
# 56     56     100     0.56       1983
# 57     57     100     0.57       1983
# 58     58     100     0.58       1984
# 59     59     100     0.59       1984
# 60     60     100     0.60       1985
# 61     61     100     0.61       1985
# 62     62     100     0.62       1986
# 63     63     100     0.63       1986
# 64     64     100     0.64       1987
# 65     65     100     0.65       1988
# 66     66     100     0.66       1988
# 67     67     100     0.67       1989
# 68     68     100     0.68       1989
# 69     69     100     0.69       1990
# 70     70     100     0.70       1990
# 71     71     100     0.71       1991
# 72     72     100     0.72       1991
# 73     73     100     0.73       1992
# 74     74     100     0.74       1993
# 75     75     100     0.75       1993
# 76     76     100     0.76       1994
# 77     77     100     0.77       1994
# 78     78     100     0.78       1995
# 79     79     100     0.79       1995
# 80     80     100     0.80       1996
# 81     81     100     0.81       1996
# 82     82     100     0.82       1997
# 83     83     100     0.83       1998
# 84     84     100     0.84       1998
# 85     85     100     0.85       1999
# 86     86     100     0.86       1999
# 87     87     100     0.87       2000
# 88     88     100     0.88       2000
# 89     89     100     0.89       2001
# 90     90     100     0.90       2001
# 91     91     100     0.91       2002
# 92     92     100     0.92       2003
# 93     93     100     0.93       2003
# 94     94     100     0.94       2004
# 95     95     100     0.95       2004
# 96     96     100     0.96       2005
# 97     97     100     0.97       2005
# 98     98     100     0.98       2006
# 99     99     100     0.99       2006
# 100   100     100     1.00       2007
#                                                                                frame_source
# 1   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0001.png
# 2   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0002.png
# 3   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0003.png
# 4   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0004.png
# 5   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0005.png
# 6   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0006.png
# 7   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0007.png
# 8   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0008.png
# 9   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0009.png
# 10  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0010.png
# 11  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0011.png
# 12  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0012.png
# 13  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0013.png
# 14  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0014.png
# 15  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0015.png
# 16  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0016.png
# 17  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0017.png
# 18  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0018.png
# 19  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0019.png
# 20  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0020.png
# 21  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0021.png
# 22  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0022.png
# 23  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0023.png
# 24  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0024.png
# 25  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0025.png
# 26  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0026.png
# 27  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0027.png
# 28  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0028.png
# 29  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0029.png
# 30  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0030.png
# 31  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0031.png
# 32  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0032.png
# 33  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0033.png
# 34  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0034.png
# 35  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0035.png
# 36  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0036.png
# 37  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0037.png
# 38  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0038.png
# 39  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0039.png
# 40  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0040.png
# 41  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0041.png
# 42  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0042.png
# 43  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0043.png
# 44  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0044.png
# 45  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0045.png
# 46  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0046.png
# 47  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0047.png
# 48  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0048.png
# 49  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0049.png
# 50  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0050.png
# 51  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0051.png
# 52  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0052.png
# 53  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0053.png
# 54  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0054.png
# 55  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0055.png
# 56  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0056.png
# 57  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0057.png
# 58  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0058.png
# 59  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0059.png
# 60  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0060.png
# 61  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0061.png
# 62  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0062.png
# 63  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0063.png
# 64  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0064.png
# 65  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0065.png
# 66  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0066.png
# 67  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0067.png
# 68  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0068.png
# 69  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0069.png
# 70  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0070.png
# 71  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0071.png
# 72  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0072.png
# 73  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0073.png
# 74  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0074.png
# 75  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0075.png
# 76  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0076.png
# 77  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0077.png
# 78  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0078.png
# 79  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0079.png
# 80  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0080.png
# 81  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0081.png
# 82  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0082.png
# 83  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0083.png
# 84  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0084.png
# 85  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0085.png
# 86  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0086.png
# 87  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0087.png
# 88  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0088.png
# 89  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0089.png
# 90  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0090.png
# 91  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0091.png
# 92  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0092.png
# 93  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0093.png
# 94  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0094.png
# 95  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0095.png
# 96  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0096.png
# 97  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0097.png
# 98  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0098.png
# 99  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0099.png
# 100 C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\30685ab8154a/gganim_plot0100.png

# %%
p <- ggplot(iris, aes(x = Petal.Width, y = Petal.Length)) + 
  geom_point()

plot(p)
# Out:
# plot without title

# %%
anim <- p + 
  transition_states(Species,
                    transition_length = 2,
                    state_length = 1)

anim
# Out:
# Rendering [=>-------------------------------------------] at 17 fps ~ eta:  6s
#
# Rendering [==>------------------------------------------] at 17 fps ~ eta:  6s
#
# Rendering [==>------------------------------------------] at 16 fps ~ eta:  6s
#
# Rendering [===>-----------------------------------------] at 16 fps ~ eta:  6s
#
# Rendering [====>----------------------------------------] at 16 fps ~ eta:  6s
#
# Rendering [=====>---------------------------------------] at 16 fps ~ eta:  5s
#
# Rendering [======>--------------------------------------] at 16 fps ~ eta:  5s
#
# Rendering [=======>-------------------------------------] at 16 fps ~ eta:  5s
#
# Rendering [=======>-------------------------------------] at 15 fps ~ eta:  5s
#
# Rendering [========>------------------------------------] at 15 fps ~ eta:  5s
#
# Rendering [=========>-----------------------------------] at 15 fps ~ eta:  5s
#
# Rendering [==========>----------------------------------] at 15 fps ~ eta:  5s
#
# Rendering [===========>---------------------------------] at 15 fps ~ eta:  5s
#
# Rendering [============>--------------------------------] at 15 fps ~ eta:  5s
#
# Rendering [=============>-------------------------------] at 15 fps ~ eta:  5s
#
# Rendering [==============>------------------------------] at 15 fps ~ eta:  4s
#
# Rendering [===============>-----------------------------] at 15 fps ~ eta:  4s
#
# Rendering [================>----------------------------] at 15 fps ~ eta:  4s
#
# Rendering [=================>---------------------------] at 15 fps ~ eta:  4s
#
# Rendering [==================>--------------------------] at 15 fps ~ eta:  4s
#
# Rendering [===================>-------------------------] at 15 fps ~ eta:  4s
#
# Rendering [====================>------------------------] at 15 fps ~ eta:  4s
#
# Rendering [=====================>-----------------------] at 15 fps ~ eta:  3s
#
# Rendering [======================>----------------------] at 15 fps ~ eta:  3s
#
# Rendering [=======================>---------------------] at 15 fps ~ eta:  3s
#
# Rendering [========================>--------------------] at 15 fps ~ eta:  3s
#
# Rendering [=========================>-------------------] at 15 fps ~ eta:  3s
#
# Rendering [==========================>------------------] at 15 fps ~ eta:  3s
#
# Rendering [===========================>-----------------] at 15 fps ~ eta:  3s
#
# Rendering [===========================>-----------------] at 15 fps ~ eta:  2s
#
# Rendering [============================>----------------] at 15 fps ~ eta:  2s
#
# Rendering [=============================>---------------] at 15 fps ~ eta:  2s
#
# Rendering [==============================>--------------] at 15 fps ~ eta:  2s
#
# Rendering [===============================>-------------] at 15 fps ~ eta:  2s
#
# Rendering [================================>------------] at 15 fps ~ eta:  2s
#
# Rendering [=================================>-----------] at 15 fps ~ eta:  2s
#
# Rendering [==================================>----------] at 15 fps ~ eta:  2s
#
# Rendering [==================================>----------] at 15 fps ~ eta:  1s
#
# Rendering [===================================>---------] at 15 fps ~ eta:  1s
#
# Rendering [====================================>--------] at 15 fps ~ eta:  1s
#
# Rendering [=====================================>-------] at 15 fps ~ eta:  1s
#
# Rendering [======================================>------] at 15 fps ~ eta:  1s
#
# Rendering [=======================================>-----] at 15 fps ~ eta:  1s
#
# Rendering [========================================>----] at 15 fps ~ eta:  1s
#
# Rendering [=========================================>---] at 15 fps ~ eta:  0s
#
# Rendering [==========================================>--] at 15 fps ~ eta:  0s
#
# Rendering [===========================================>-] at 15 fps ~ eta:  0s
#
# Rendering [============================================>] at 15 fps ~ eta:  0s
#
# Rendering [=============================================] at 15 fps ~ eta:  0s
#
#
# Warning message:
# "file_renderer failed to copy frames to the destination directory"
# ERROR while rich displaying an object: Error in loadNamespace(name): there is no package called 'plotly'
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_plotly1.ggplot(obj)
# 9. fromJSON(plotly::plotly_json(obj, jsonedit = FALSE))
# 10. plotly::plotly_json
# 11. getExportedValue(pkg, name)
# 12. asNamespace(ns)
# 13. getNamespace(ns)
# 14. loadNamespace(name)
# 15. withRestarts(stop(cond), retry_loadNamespace = function() NULL)
# 16. withOneRestart(expr, restarts[[1L]])
# 17. doWithOneRestart(return(expr), restart)
#   [1] "./gganim_plot0001.png" "./gganim_plot0002.png" "./gganim_plot0003.png"
#   [4] "./gganim_plot0004.png" "./gganim_plot0005.png" "./gganim_plot0006.png"
#   [7] "./gganim_plot0007.png" "./gganim_plot0008.png" "./gganim_plot0009.png"
#  [10] "./gganim_plot0010.png" "./gganim_plot0011.png" "./gganim_plot0012.png"
#  [13] "./gganim_plot0013.png" "./gganim_plot0014.png" "./gganim_plot0015.png"
#  [16] "./gganim_plot0016.png" "./gganim_plot0017.png" "./gganim_plot0018.png"
#  [19] "./gganim_plot0019.png" "./gganim_plot0020.png" "./gganim_plot0021.png"
#  [22] "./gganim_plot0022.png" "./gganim_plot0023.png" "./gganim_plot0024.png"
#  [25] "./gganim_plot0025.png" "./gganim_plot0026.png" "./gganim_plot0027.png"
#  [28] "./gganim_plot0028.png" "./gganim_plot0029.png" "./gganim_plot0030.png"
#  [31] "./gganim_plot0031.png" "./gganim_plot0032.png" "./gganim_plot0033.png"
#  [34] "./gganim_plot0034.png" "./gganim_plot0035.png" "./gganim_plot0036.png"
#  [37] "./gganim_plot0037.png" "./gganim_plot0038.png" "./gganim_plot0039.png"
#  [40] "./gganim_plot0040.png" "./gganim_plot0041.png" "./gganim_plot0042.png"
#  [43] "./gganim_plot0043.png" "./gganim_plot0044.png" "./gganim_plot0045.png"
#  [46] "./gganim_plot0046.png" "./gganim_plot0047.png" "./gganim_plot0048.png"
#  [49] "./gganim_plot0049.png" "./gganim_plot0050.png" "./gganim_plot0051.png"
#  [52] "./gganim_plot0052.png" "./gganim_plot0053.png" "./gganim_plot0054.png"
#  [55] "./gganim_plot0055.png" "./gganim_plot0056.png" "./gganim_plot0057.png"
#  [58] "./gganim_plot0058.png" "./gganim_plot0059.png" "./gganim_plot0060.png"
#  [61] "./gganim_plot0061.png" "./gganim_plot0062.png" "./gganim_plot0063.png"
#  [64] "./gganim_plot0064.png" "./gganim_plot0065.png" "./gganim_plot0066.png"
#  [67] "./gganim_plot0067.png" "./gganim_plot0068.png" "./gganim_plot0069.png"
#  [70] "./gganim_plot0070.png" "./gganim_plot0071.png" "./gganim_plot0072.png"
#  [73] "./gganim_plot0073.png" "./gganim_plot0074.png" "./gganim_plot0075.png"
#  [76] "./gganim_plot0076.png" "./gganim_plot0077.png" "./gganim_plot0078.png"
#  [79] "./gganim_plot0079.png" "./gganim_plot0080.png" "./gganim_plot0081.png"
#  [82] "./gganim_plot0082.png" "./gganim_plot0083.png" "./gganim_plot0084.png"
#  [85] "./gganim_plot0085.png" "./gganim_plot0086.png" "./gganim_plot0087.png"
#  [88] "./gganim_plot0088.png" "./gganim_plot0089.png" "./gganim_plot0090.png"
#  [91] "./gganim_plot0091.png" "./gganim_plot0092.png" "./gganim_plot0093.png"
#  [94] "./gganim_plot0094.png" "./gganim_plot0095.png" "./gganim_plot0096.png"
#  [97] "./gganim_plot0097.png" "./gganim_plot0098.png" "./gganim_plot0099.png"
# [100] "./gganim_plot0100.png"
# attr(,"frame_vars")
#     frame nframes progress transitioning previous_state closest_state
# 1       1     100     0.01         FALSE         setosa        setosa
# 2       2     100     0.02         FALSE         setosa        setosa
# 3       3     100     0.03         FALSE         setosa        setosa
# 4       4     100     0.04         FALSE         setosa        setosa
# 5       5     100     0.05         FALSE         setosa        setosa
# 6       6     100     0.06         FALSE         setosa        setosa
# 7       7     100     0.07         FALSE         setosa        setosa
# 8       8     100     0.08         FALSE         setosa        setosa
# 9       9     100     0.09         FALSE         setosa        setosa
# 10     10     100     0.10         FALSE         setosa        setosa
# 11     11     100     0.11         FALSE         setosa        setosa
# 12     12     100     0.12         FALSE         setosa        setosa
# 13     13     100     0.13          TRUE         setosa        setosa
# 14     14     100     0.14          TRUE         setosa        setosa
# 15     15     100     0.15          TRUE         setosa        setosa
# 16     16     100     0.16          TRUE         setosa        setosa
# 17     17     100     0.17          TRUE         setosa        setosa
# 18     18     100     0.18          TRUE         setosa        setosa
# 19     19     100     0.19          TRUE         setosa        setosa
# 20     20     100     0.20          TRUE         setosa        setosa
# 21     21     100     0.21          TRUE         setosa        setosa
# 22     22     100     0.22          TRUE         setosa        setosa
# 23     23     100     0.23          TRUE         setosa        setosa
# 24     24     100     0.24          TRUE         setosa    versicolor
# 25     25     100     0.25          TRUE         setosa    versicolor
# 26     26     100     0.26          TRUE         setosa    versicolor
# 27     27     100     0.27          TRUE         setosa    versicolor
# 28     28     100     0.28          TRUE         setosa    versicolor
# 29     29     100     0.29          TRUE         setosa    versicolor
# 30     30     100     0.30          TRUE         setosa    versicolor
# 31     31     100     0.31          TRUE         setosa    versicolor
# 32     32     100     0.32          TRUE         setosa    versicolor
# 33     33     100     0.33          TRUE         setosa    versicolor
# 34     34     100     0.34          TRUE         setosa    versicolor
# 35     35     100     0.35         FALSE     versicolor    versicolor
# 36     36     100     0.36         FALSE     versicolor    versicolor
# 37     37     100     0.37         FALSE     versicolor    versicolor
# 38     38     100     0.38         FALSE     versicolor    versicolor
# 39     39     100     0.39         FALSE     versicolor    versicolor
# 40     40     100     0.40         FALSE     versicolor    versicolor
# 41     41     100     0.41         FALSE     versicolor    versicolor
# 42     42     100     0.42         FALSE     versicolor    versicolor
# 43     43     100     0.43         FALSE     versicolor    versicolor
# 44     44     100     0.44         FALSE     versicolor    versicolor
# 45     45     100     0.45         FALSE     versicolor    versicolor
# 46     46     100     0.46         FALSE     versicolor    versicolor
# 47     47     100     0.47          TRUE     versicolor    versicolor
# 48     48     100     0.48          TRUE     versicolor    versicolor
# 49     49     100     0.49          TRUE     versicolor    versicolor
# 50     50     100     0.50          TRUE     versicolor    versicolor
# 51     51     100     0.51          TRUE     versicolor    versicolor
# 52     52     100     0.52          TRUE     versicolor    versicolor
# 53     53     100     0.53          TRUE     versicolor    versicolor
# 54     54     100     0.54          TRUE     versicolor    versicolor
# 55     55     100     0.55          TRUE     versicolor    versicolor
# 56     56     100     0.56          TRUE     versicolor    versicolor
# 57     57     100     0.57          TRUE     versicolor    versicolor
# 58     58     100     0.58          TRUE     versicolor     virginica
# 59     59     100     0.59          TRUE     versicolor     virginica
# 60     60     100     0.60          TRUE     versicolor     virginica
# 61     61     100     0.61          TRUE     versicolor     virginica
# 62     62     100     0.62          TRUE     versicolor     virginica
# 63     63     100     0.63          TRUE     versicolor     virginica
# 64     64     100     0.64          TRUE     versicolor     virginica
# 65     65     100     0.65          TRUE     versicolor     virginica
# 66     66     100     0.66          TRUE     versicolor     virginica
# 67     67     100     0.67          TRUE     versicolor     virginica
# 68     68     100     0.68          TRUE     versicolor     virginica
# 69     69     100     0.69         FALSE      virginica     virginica
# 70     70     100     0.70         FALSE      virginica     virginica
# 71     71     100     0.71         FALSE      virginica     virginica
# 72     72     100     0.72         FALSE      virginica     virginica
# 73     73     100     0.73         FALSE      virginica     virginica
# 74     74     100     0.74         FALSE      virginica     virginica
# 75     75     100     0.75         FALSE      virginica     virginica
# 76     76     100     0.76         FALSE      virginica     virginica
# 77     77     100     0.77         FALSE      virginica     virginica
# 78     78     100     0.78         FALSE      virginica     virginica
# 79     79     100     0.79         FALSE      virginica     virginica
# 80     80     100     0.80         FALSE      virginica     virginica
# 81     81     100     0.81          TRUE      virginica     virginica
# 82     82     100     0.82          TRUE      virginica     virginica
# 83     83     100     0.83          TRUE      virginica     virginica
# 84     84     100     0.84          TRUE      virginica     virginica
# 85     85     100     0.85          TRUE      virginica     virginica
# 86     86     100     0.86          TRUE      virginica     virginica
# 87     87     100     0.87          TRUE      virginica     virginica
# 88     88     100     0.88          TRUE      virginica     virginica
# 89     89     100     0.89          TRUE      virginica     virginica
# 90     90     100     0.90          TRUE      virginica     virginica
# 91     91     100     0.91          TRUE      virginica     virginica
# 92     92     100     0.92          TRUE      virginica        setosa
# 93     93     100     0.93          TRUE      virginica        setosa
# 94     94     100     0.94          TRUE      virginica        setosa
# 95     95     100     0.95          TRUE      virginica        setosa
# 96     96     100     0.96          TRUE      virginica        setosa
# 97     97     100     0.97          TRUE      virginica        setosa
# 98     98     100     0.98          TRUE      virginica        setosa
# 99     99     100     0.99          TRUE      virginica        setosa
# 100   100     100     1.00          TRUE      virginica        setosa
#     next_state
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# 5       setosa
# 6       setosa
# 7       setosa
# 8       setosa
# 9       setosa
# 10      setosa
# 11      setosa
# 12      setosa
# 13  versicolor
# 14  versicolor
# 15  versicolor
# 16  versicolor
# 17  versicolor
# 18  versicolor
# 19  versicolor
# 20  versicolor
# 21  versicolor
# 22  versicolor
# 23  versicolor
# 24  versicolor
# 25  versicolor
# 26  versicolor
# 27  versicolor
# 28  versicolor
# 29  versicolor
# 30  versicolor
# 31  versicolor
# 32  versicolor
# 33  versicolor
# 34  versicolor
# 35  versicolor
# 36  versicolor
# 37  versicolor
# 38  versicolor
# 39  versicolor
# 40  versicolor
# 41  versicolor
# 42  versicolor
# 43  versicolor
# 44  versicolor
# 45  versicolor
# 46  versicolor
# 47   virginica
# 48   virginica
# 49   virginica
# 50   virginica
# 51   virginica
# 52   virginica
# 53   virginica
# 54   virginica
# 55   virginica
# 56   virginica
# 57   virginica
# 58   virginica
# 59   virginica
# 60   virginica
# 61   virginica
# 62   virginica
# 63   virginica
# 64   virginica
# 65   virginica
# 66   virginica
# 67   virginica
# 68   virginica
# 69   virginica
# 70   virginica
# 71   virginica
# 72   virginica
# 73   virginica
# 74   virginica
# 75   virginica
# 76   virginica
# 77   virginica
# 78   virginica
# 79   virginica
# 80   virginica
# 81      setosa
# 82      setosa
# 83      setosa
# 84      setosa
# 85      setosa
# 86      setosa
# 87      setosa
# 88      setosa
# 89      setosa
# 90      setosa
# 91      setosa
# 92      setosa
# 93      setosa
# 94      setosa
# 95      setosa
# 96      setosa
# 97      setosa
# 98      setosa
# 99      setosa
# 100     setosa
#                                                                             frame_source
# 1   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0001.png
# 2   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0002.png
# 3   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0003.png
# 4   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0004.png
# 5   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0005.png
# 6   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0006.png
# 7   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0007.png
# 8   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0008.png
# 9   C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0009.png
# 10  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0010.png
# 11  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0011.png
# 12  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0012.png
# 13  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0013.png
# 14  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0014.png
# 15  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0015.png
# 16  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0016.png
# 17  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0017.png
# 18  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0018.png
# 19  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0019.png
# 20  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0020.png
# 21  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0021.png
# 22  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0022.png
# 23  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0023.png
# 24  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0024.png
# 25  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0025.png
# 26  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0026.png
# 27  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0027.png
# 28  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0028.png
# 29  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0029.png
# 30  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0030.png
# 31  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0031.png
# 32  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0032.png
# 33  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0033.png
# 34  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0034.png
# 35  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0035.png
# 36  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0036.png
# 37  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0037.png
# 38  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0038.png
# 39  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0039.png
# 40  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0040.png
# 41  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0041.png
# 42  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0042.png
# 43  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0043.png
# 44  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0044.png
# 45  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0045.png
# 46  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0046.png
# 47  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0047.png
# 48  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0048.png
# 49  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0049.png
# 50  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0050.png
# 51  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0051.png
# 52  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0052.png
# 53  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0053.png
# 54  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0054.png
# 55  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0055.png
# 56  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0056.png
# 57  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0057.png
# 58  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0058.png
# 59  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0059.png
# 60  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0060.png
# 61  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0061.png
# 62  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0062.png
# 63  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0063.png
# 64  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0064.png
# 65  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0065.png
# 66  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0066.png
# 67  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0067.png
# 68  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0068.png
# 69  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0069.png
# 70  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0070.png
# 71  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0071.png
# 72  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0072.png
# 73  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0073.png
# 74  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0074.png
# 75  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0075.png
# 76  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0076.png
# 77  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0077.png
# 78  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0078.png
# 79  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0079.png
# 80  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0080.png
# 81  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0081.png
# 82  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0082.png
# 83  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0083.png
# 84  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0084.png
# 85  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0085.png
# 86  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0086.png
# 87  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0087.png
# 88  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0088.png
# 89  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0089.png
# 90  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0090.png
# 91  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0091.png
# 92  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0092.png
# 93  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0093.png
# 94  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0094.png
# 95  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0095.png
# 96  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0096.png
# 97  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0097.png
# 98  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0098.png
# 99  C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0099.png
# 100 C:\\Users\\MALIPO~1\\AppData\\Local\\Temp\\RtmpUjjPbx\\3068bb850/gganim_plot0100.png
